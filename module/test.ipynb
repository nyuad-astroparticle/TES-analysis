# %%
import pca
# %matplotlib widget

# %%
path = '/home/Artem/TES-analysis/1TES_3PMTs'
test = pca.PCA(path, 'C4')
# Out:
# Trigger for channel C4 is set to: -33.0 mV
# Traces for channel C4 loaded: 963
# Aquisition start time: 2023-10-17 18:35:29.569026
# End time: 2023-10-18 08:22:48.234000
# Total time of the run (hh:mm:ss): 13:47:18.664974
# Reference pulses loaded successfully.
# Number of signals triggered: 963
# Not triggered: 0

# %%
test.KMeans_clustering(3)
# Out:
#   0%|          | 0/963 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 170
# ...

# %%
test.reset_pyper()

# %%
test.pyper
# Out:
# [870,
#  array([  2,  47,  82,  83,  86,  89,  90,  96, 101, 103, 107, 139, 157,
#         162, 164, 173, 176, 177, 178, 180, 181, 184, 185, 186, 194, 196,
#         199, 201, 204, 205, 214, 217, 224, 234, 237, 239, 240, 243, 244,
#         254, 262, 263, 267, 274, 275, 278, 279, 285, 289, 294, 295, 296,
#         303, 307, 308, 310, 325, 333, 334, 341, 343, 344, 347, 348, 352,
#         358, 359, 360, 368, 371, 379, 381, 382, 383, 385, 386, 388, 389,
#         397, 398, 399, 404, 407, 409, 410, 419, 423, 426, 430, 436, 437,
#         443, 444, 451, 455, 464, 477, 480, 485, 487, 488, 499, 500, 503,
#         507, 517, 528, 530, 531, 533, 534, 547, 550, 569, 578, 583, 585,
#         586, 587, 597, 604, 616, 619, 620, 623, 624, 625, 638, 639, 640,
#         641, 642, 654, 657, 658, 662, 666, 676, 677, 680, 694, 695, 703,
#         704, 706, 710, 711, 719, 725, 726, 729, 730, 733, 738, 739, 744,
#         750, 759, 765, 766, 777, 778, 779, 792, 793, 796, 798, 811, 817,
# ...

# %%
test.secondary_feature_reduction(order = 2, mysize = 1/250)
# Out:
#   0%|          | 0/583 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test.secondary_KMeans_clustering(3,1,3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 272
# ...
